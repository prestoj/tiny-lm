# %%
import pandas as pd
import numpy as np
import math

df = pd.read_csv('gutenberg_metadata.csv')

# %%
f'{len(df[df['Language'] == 'en'])} English Books | {len(df)} Total Books'
# Out:
# '60177 English Books | 75394 Total Books'

# %%
df
# Out:
#        Etext Number  Type      Issued  \
# 0                 1  Text  1971-12-01
# 1                 2  Text  1972-12-01
# 2                 3  Text  1973-11-01
# 3                 4  Text  1973-11-01
# 4                 5  Text  1975-12-01
# ...             ...   ...         ...
# 75389         75565  Text  2025-03-08
# 75390         75566  Text  2025-03-08
# 75391         75567  Text  2025-03-09
# 75392         75568  Text  2025-03-09
# 75393         75569  Text  2025-03-09
#
#                                                    Title Language      LoCC  \
# 0      The Declaration of Independence of the United ...       en  E201; JK
# 1      The United States Bill of Rights\r\nThe Ten Or...       en    JK; KF
# 2                    John F. Kennedy's Inaugural Address       en      E838
# 3      Lincoln's Gettysburg Address\r\nGiven November...       en      E456
# 4                         The United States Constitution       en    JK; KF
# ...
